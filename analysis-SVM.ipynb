# %%
from pathlib import Path, PurePath
from tensorflow.keras.preprocessing import image_dataset_from_directory
from skimage.transform import resize
from skimage.io import imread
from sklearn.model_selection import train_test_split
import numpy as np

# %%
from numpy.random import default_rng
rng = default_rng(1337)
samples_path = Path("data/processed/crop_6_1000x1000/")

# %%
categories = ["dc", "marvel"]
target_arr, flat_data_arr = [], []
number_of_samples = 100
for idx, category in enumerate(categories):
    print(f'Loading category : {category}')
    
    dir_path = samples_path / category
    # reproducable with seed set
    files = rng.permutation(list(dir_path.iterdir()))[:number_of_samples]
    
     # Anti Aliasing recomended for down scaling
    category_imgs = [resize(imread(img_path),(256,256,3), anti_aliasing=True).flatten() for img_path in files]
    flat_data_arr.extend(category_imgs)
    target_arr.extend([idx]*len(category_imgs))
    
flattened_X = np.array(flat_data_arr)
y = np.array(target_arr)
# Out:
# Loading category : dc
# Loading category : marvel

# %%
X_train, X_test, y_train, y_test = train_test_split(flattened_X, y, test_size=0.2, random_state=7)

# %%
from sklearn import svm
from sklearn.model_selection import GridSearchCV

# Find the best hyper parameters -- Could also try sigmoid/linear, also could try different degrees of poly
param_grid = {'C':[0.1,1,10,100],'gamma':[0.0001,0.001,0.1,1],'kernel':['rbf','poly']}

# uses 5-fold-validation, but not necessary (there wasn't much variance in first run)
# Second without 5-fold runs better, but might be because of split
svc = svm.SVC(probability=False) 
model = GridSearchCV(svc, param_grid, verbose=3, n_jobs=-2)
model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# GridSearchCV(estimator=SVC(), n_jobs=-2,
#              param_grid={'C': [0.1, 1, 10, 100],
#                          'gamma': [0.0001, 0.001, 0.1, 1],
#                          'kernel': ['rbf', 'poly']},
#              verbose=3)

# %%
import pandas as pd
results_df = pd.DataFrame(model.cv_results_)
results_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       23.993750      3.862507        23.018929        1.336222     0.1
# 1       22.942210      2.582910         4.206371        1.427359     0.1
# 2       20.940199      0.196059        21.312260        0.894461     0.1
# 3       20.547232      0.714048         4.590426        0.388352     0.1
# 4       21.550017      0.513518        19.562404        0.329324     0.1
# 5       21.116367      0.908790         4.724201        0.570733     0.1
# 6       22.604183      1.235051        20.984211        0.526172     0.1
# 7       20.779512      0.512679         5.195282        1.139855     0.1
# 8       22.737138      1.244707        20.831655        1.049457       1
# 9       20.475662      0.382211         4.677055        0.150289       1
# 10      21.351406      0.373721        20.732277        1.158038       1
# 11      22.567841      1.283000         4.947399        0.584930       1
# 12      25.231399      1.818202        22.973997        1.714016       1
# 13      23.073605      1.186017         5.545196        0.513154       1
# 14      24.397399      0.542703        22.522801        0.741296       1
# 15      23.124794      0.979674         5.325799        0.523086       1
# 16      24.315002      1.124001        25.572646        2.319986      10
# 17      21.854052      2.046438         4.632248        0.662064      10
# 18      20.618598      0.833699        18.814001        0.449559      10
# 19      19.211798      0.225032         4.219003        0.195506      10
# 20      19.866595      0.449323        18.686803        0.436832      10
# 21      19.155998      0.271883         4.036199        0.267743      10
# 22      19.668797      0.152198        18.804400        0.543934      10
# 23      19.296399      0.420472         4.260199        0.170970      10
# 24      20.191601      0.403421        18.729800        0.450944     100
# 25      19.150197      0.164286         4.153004        0.123317     100
# 26      19.410998      0.200333        18.827601        0.327133     100
# 27      19.927398      0.624989         3.985399        0.296492     100
# 28      20.648197      0.590288        19.277599        0.544497     100
# 29      19.642593      0.743962         4.151601        0.118422     100
# 30      19.824197      0.203485        17.756203        1.812400     100
# 31      14.885412      3.624588         2.538996        1.172144     100
#
#    param_gamma param_kernel                                         params  \
# 0       0.0001          rbf   {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 1       0.0001         poly  {'C': 0.1, 'gamma': 0.0001, 'kernel': 'poly'}
# 2        0.001          rbf    {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# 3        0.001         poly   {'C': 0.1, 'gamma': 0.001, 'kernel': 'poly'}
# 4          0.1          rbf      {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 5          0.1         poly     {'C': 0.1, 'gamma': 0.1, 'kernel': 'poly'}
# 6            1          rbf        {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# 7            1         poly       {'C': 0.1, 'gamma': 1, 'kernel': 'poly'}
# 8       0.0001          rbf     {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 9       0.0001         poly    {'C': 1, 'gamma': 0.0001, 'kernel': 'poly'}
# 10       0.001          rbf      {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 11       0.001         poly     {'C': 1, 'gamma': 0.001, 'kernel': 'poly'}
# 12         0.1          rbf        {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 13         0.1         poly       {'C': 1, 'gamma': 0.1, 'kernel': 'poly'}
# 14           1          rbf          {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# 15           1         poly         {'C': 1, 'gamma': 1, 'kernel': 'poly'}
# 16      0.0001          rbf    {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 17      0.0001         poly   {'C': 10, 'gamma': 0.0001, 'kernel': 'poly'}
# 18       0.001          rbf     {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 19       0.001         poly    {'C': 10, 'gamma': 0.001, 'kernel': 'poly'}
# 20         0.1          rbf       {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 21         0.1         poly      {'C': 10, 'gamma': 0.1, 'kernel': 'poly'}
# 22           1          rbf         {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 23           1         poly        {'C': 10, 'gamma': 1, 'kernel': 'poly'}
# 24      0.0001          rbf   {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 25      0.0001         poly  {'C': 100, 'gamma': 0.0001, 'kernel': 'poly'}
# 26       0.001          rbf    {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 27       0.001         poly   {'C': 100, 'gamma': 0.001, 'kernel': 'poly'}
# 28         0.1          rbf      {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# 29         0.1         poly     {'C': 100, 'gamma': 0.1, 'kernel': 'poly'}
# 30           1          rbf        {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# 31           1         poly       {'C': 100, 'gamma': 1, 'kernel': 'poly'}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0             0.50000            0.50000            0.53125
# 1             0.59375            0.59375            0.59375
# 2             0.50000            0.50000            0.53125
# 3             0.53125            0.62500            0.59375
# 4             0.50000            0.50000            0.53125
# 5             0.53125            0.62500            0.59375
# 6             0.50000            0.50000            0.53125
# 7             0.53125            0.62500            0.59375
# 8             0.50000            0.62500            0.62500
# 9             0.53125            0.53125            0.62500
# 10            0.50000            0.50000            0.53125
# 11            0.53125            0.62500            0.59375
# 12            0.50000            0.50000            0.53125
# 13            0.53125            0.62500            0.59375
# 14            0.50000            0.50000            0.53125
# 15            0.53125            0.62500            0.59375
# 16            0.56250            0.59375            0.65625
# 17            0.53125            0.62500            0.59375
# 18            0.50000            0.50000            0.53125
# 19            0.53125            0.62500            0.59375
# 20            0.50000            0.50000            0.53125
# 21            0.53125            0.62500            0.59375
# 22            0.50000            0.50000            0.53125
# 23            0.53125            0.62500            0.59375
# 24            0.56250            0.59375            0.65625
# 25            0.53125            0.62500            0.59375
# 26            0.50000            0.50000            0.53125
# 27            0.53125            0.62500            0.59375
# 28            0.50000            0.50000            0.53125
# 29            0.53125            0.62500            0.59375
# 30            0.50000            0.50000            0.53125
# 31            0.53125            0.62500            0.59375
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0             0.53125            0.53125          0.51875        0.015309
# 1             0.62500            0.50000          0.58125        0.042390
# 2             0.53125            0.53125          0.51875        0.015309
# 3             0.59375            0.40625          0.55000        0.078062
# 4             0.53125            0.53125          0.51875        0.015309
# 5             0.59375            0.40625          0.55000        0.078062
# 6             0.53125            0.53125          0.51875        0.015309
# 7             0.59375            0.40625          0.55000        0.078062
# 8             0.65625            0.56250          0.59375        0.055902
# 9             0.53125            0.40625          0.52500        0.069597
# 10            0.53125            0.53125          0.51875        0.015309
# 11            0.59375            0.40625          0.55000        0.078062
# 12            0.53125            0.53125          0.51875        0.015309
# 13            0.59375            0.40625          0.55000        0.078062
# 14            0.53125            0.53125          0.51875        0.015309
# 15            0.59375            0.40625          0.55000        0.078062
# 16            0.56250            0.56250          0.58750        0.036443
# 17            0.59375            0.40625          0.55000        0.078062
# 18            0.53125            0.53125          0.51875        0.015309
# 19            0.59375            0.40625          0.55000        0.078062
# 20            0.53125            0.53125          0.51875        0.015309
# 21            0.59375            0.40625          0.55000        0.078062
# 22            0.53125            0.53125          0.51875        0.015309
# 23            0.59375            0.40625          0.55000        0.078062
# 24            0.56250            0.56250          0.58750        0.036443
# 25            0.59375            0.40625          0.55000        0.078062
# 26            0.53125            0.53125          0.51875        0.015309
# 27            0.59375            0.40625          0.55000        0.078062
# 28            0.53125            0.53125          0.51875        0.015309
# 29            0.59375            0.40625          0.55000        0.078062
# 30            0.53125            0.53125          0.51875        0.015309
# 31            0.59375            0.40625          0.55000        0.078062
#
#     rank_test_score
# 0                20
# 1                 4
# 2                20
# 3                 5
# 4                20
# 5                 5
# 6                20
# 7                 5
# 8                 1
# 9                19
# 10               20
# 11                5
# 12               20
# 13                5
# 14               20
# 15                5
# 16                2
# 17                5
# 18               20
# 19                5
# 20               20
# 21                5
# 22               20
# 23                5
# 24                2
# 25                5
# 26               20
# 27                5
# 28               20
# 29                5
# 30               20
# 31                5

# %%
model.best_params_
# Out:
# {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}

# %%
model.best_score_
# Out:
# 0.59375
